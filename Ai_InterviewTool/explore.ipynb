# %%
topic_title = """Personal"""
quries_num = """1"""
Level = """Easy"""

# %%
import requests
import os
from dotenv import load_dotenv
# Set API endpoint
load_dotenv()
api_key = os.getenv('GOOGLE_API_KEY')
endpoint = "https://generativelanguage.googleapis.com/v1beta2"

# generate the questions 
prompt = f"""

INPUT:

Role: You are an expert in generating interview questions for academic positions with a strong understanding of the client's vision.

Context: The client's requirements for a software project are analyzed. You have a solid understanding of their needs.

Level: Based on the chosen level, provide questions to help the user improve their skills.

Please generate {quries_num} interview questions for the topic {topic_title} suitable for an {Level} level interview.

Topic Choosen: {topic_title}
Number of Questions: {quries_num}

Based on the user number of questions and the topic chosen, you will generate the same number of questions in the list with the index from 1. 
"""

# prepare the request body
request_body = {
    "prompt": {
        "text": prompt
    }
}

# make the request to generative language api
response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
questions = response.json()['candidates'][0]['output']
print(f"\n{questions}")
# Out:
# 1. What is your favorite book and why?

# %%
query = "What is your favorite book and why?"
answer = "My hobbies are as follows : Investment, walking, reading old books, retro cars collestion, writting scripts, jurnalisum and also intrested in movie's making field as a director."

# %%
import requests
import os
from dotenv import load_dotenv

# Load API key from .env file
load_dotenv()
api_key = os.getenv('GOOGLE_API_KEY')
if not api_key:
    raise ValueError("API key not found. Please set the GOOGLE_API_KEY in the .env file.")

# Set API endpoint
endpoint = "https://generativelanguage.googleapis.com/v1beta2/models/text-bison-001:generateText"

# Construct the AI answer based on the provided answer and query
AI_answer = f"""
Provide feedback on the candidate's response. Please take the {query} as the question which is beign answer by the interview candidate. 
And take {answer} as the as the answer for the {query} which is asked in intherview. 

Additionally Focus on:

Overall Impression:

Positive Aspects: Highlight areas where the candidate gave a good answer, showing strong understanding or relevant experience. Mention specific points that stood out positively.
Areas for Improvement: Identify where the candidate went wrong or could have provided more detail. Explain why these areas are important and how improvement in these aspects can make a significant difference.
Content Quality:

Accuracy: Evaluate the correctness and relevance of the content in the candidate's response.
Depth: Assess whether the candidate provided sufficient depth and insight in their answer. Suggest how they could delve deeper into the topic to showcase a thorough understanding.
Clarity: Comment on the clarity and coherence of the response. Was the candidate’s answer easy to follow? Suggest ways to improve articulation and clarity.
Communication Skills:

Structure: Discuss the structure of the response. Was the answer logically organized? Suggest improvements for a more structured and persuasive answer.
Language and Tone: Evaluate the language and tone used by the candidate. Was it professional and appropriate for the context? Provide tips for using more precise or impactful language.
Specific Suggestions:

Offer specific advice on how the candidate can improve their responses to impress the interviewer. This could include tips on research, articulating thoughts, using examples, or demonstrating relevant skills and experience.
Additional Tips:

Provide any additional tips that could help the candidate perform better in future interviews. This could be general advice on interview techniques, common pitfalls to avoid, or strategies for effectively communicating their strengths.
Marks:
Assign a score out of 100 based on the overall quality of the response, considering the above criteria.
"""

# Prepare the request body
request_body = {
    "prompt": {
        "text": AI_answer
    }
}

# Make the request to the generative language API
response = requests.post(f"{endpoint}?key={api_key}", json=request_body)

# Check if the request was successful
if response.status_code == 200:
    feedback = response.json().get('candidates', [{}])[0].get('output', 'No feedback received.')
    print(feedback)
else:
    print(f"Error: {response.status_code}")
    print(response.json())
# Out:
# **Overall Impression**
#
# The candidate's response to the question "What are your hobbies outside of work?" was generally well-received by the interviewer. The candidate was able to provide a list of their hobbies, and they were able to speak about each one in a clear and concise manner. The candidate also showed enthusiasm for their hobbies, which made them more interesting to the interviewer.
#
# **Positive Aspects**
#
# * The candidate was able to provide a list of their hobbies, and they were able to speak about each one in a clear and concise manner.
# * The candidate showed enthusiasm for their hobbies, which made them more interesting to the interviewer.
# * The candidate was able to connect their hobbies to their work experience, which showed that they are a well-rounded individual.
#
# **Areas for Improvement**
#
# ...

# %%
import os
import requests
from dotenv import load_dotenv

# Load API key from environment variable
load_dotenv()
api_key = os.getenv('GOOGLE_API_KEY')

if not api_key:
    raise ValueError("No API key found. Please set the GOOGLE_API_KEY environment variable.")

# Define the API endpoint
endpoint = "https://generativelanguage.googleapis.com/v1beta2"

def get_response(user_query):
    # Create a well-structured and professional prompt
    prompt = f"""
    Role: You are an AI assistant with a strong understanding of various topics. You aim to provide clear, concise, and informative responses to user queries.

    Context: The user has asked a question. Provide a detailed and knowledgeable answer based on the information you have.

    User Query: {user_query}
    """

    # Prepare the request body
    request_body = {
        "prompt": {
            "text": prompt
        }
    }

    # Function to get response from the API
    try:
        response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
        response.raise_for_status()  # Raise an exception for HTTP errors
        data = response.json()
        answer = data.get('candidates', [])[0].get('output', '').strip()
        return answer
    except requests.exceptions.RequestException as e:
        return f"An error occurred: {e}"
    except KeyError:
        return "Unexpected response format from the API."

def main():
    print("Hello! I am your AI assistant. How can I assist you today?")
    
    while True:
        user_query = input("You: ")
        if user_query.lower() in ['exit', 'quit']:
            print("AI: Goodbye! Have a great day!")
            break
        
        response = get_response(user_query)
        print(f"AI: {response}")

if __name__ == "__main__":
    main()
# Out:
# Hello! I am your AI assistant. How can I assist you today?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 57
#      54         print(f"AI: {response}")
#      56 if __name__ == "__main__":
# ---> 57     main()
#
# Cell In[1], line 53, in main()
#      50     print("AI: Goodbye! Have a great day!")
#      51     break
# ---> 53 response = get_response(user_query)
#      54 print(f"AI: {response}")
#
# Cell In[1], line 34, in get_response(user_query)
#      32 # Function to get response from the API
#      33 try:
# ---> 34     response = requests.post(f"{endpoint}/models/text-bison-001:generateText?key={api_key}", json=request_body)
#      35     response.raise_for_status()  # Raise an exception for HTTP errors
#      36     data = response.json()
#
# ...
