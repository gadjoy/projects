# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import search_projects
from freelancersdk.resources.projects.exceptions import \
    ProjectsNotFoundException
from freelancersdk.resources.projects.helpers import (
    create_search_projects_filter,
    create_get_projects_user_details_object,
    create_get_projects_project_details_object,
)

from dotenv import load_dotenv
import os

# Load the .env file
load_dotenv()
import os


def _search_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    query = 'Python'
    limit = 50
    search_filter = create_search_projects_filter(
        sort_field= 'time_updated',
        or_search_query= True,
        languages= 'en',
    )

    try:
        p = search_projects(
            session,
            query=query,
            limit=limit,
            active_only=True,
            search_filter=search_filter,
        )

    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p


p = _search_projects()
if p:
    print('Found projects: {}'.format(p))
# Out:
# Found projects: {'projects': [{'id': 37866322, 'owner_id': 74628051, 'title': 'Instagram User Profiles Scraper', 'status': 'active', 'sub_status': None, 'seo_url': 'python/Instagram-User-Profiles-Scraper', 'currency': {'id': 1, 'code': 'USD', 'sign': '$', 'name': 'US Dollar', 'exchange_rate': 1.0, 'country': 'US', 'is_external': False, 'is_escrowcom_supported': True}, 'description': None, 'jobs': None, 'submitdate': 1710177697, 'preview_description': "I'm seeking a skilled developer, proficient in Python, to carry out a specific scraping assignment o", 'deleted': False, 'nonpublic': False, 'hidebids': False, 'type': 'fixed', 'bidperiod': 7, 'budget': {'minimum': 10.0, 'maximum': 30.0, 'name': None, 'project_type': None, 'currency_id': None}, 'hourly_project_info': None, 'featured': False, 'urgent': False, 'assisted': None, 'active_prepaid_milestone': None, 'bid_stats': {'bid_count': 9, 'bid_avg': 28.0}, 'time_submitted': 1710177697, 'time_updated': 1710177697, 'upgrades': {'featured': False, 'sealed': False, 'nonpublic': False, 'fulltime': False, 'urgent': False, 'qualified': False, 'NDA': False, 'assisted': None, 'active_prepaid_milestone': None, 'ip_contract': False, 'success_bundle': None, 'non_compete': False, 'project_management': False, 'pf_only': False, 'recruiter': None, 'listed': None, 'extend': None, 'unpaid_recruiter': None, 'premium': False, 'enterprise': False}, 'qualifications': None, 'language': 'en', 'attachments': None, 'hireme': False, 'hireme_initial_bid': None, 'invited_freelancers': None, 'recommended_freelancers': None, 'frontend_project_status': 'open', 'nda_signatures': None, 'location': {'country': {'name': None, 'flag_url': None, 'code': None, 'highres_flag_url': None, 'flag_url_cdn': None, 'highres_flag_url_cdn': None, 'iso3': None, 'region_id': None, 'phone_code': None, 'demonym': None, 'person': None, 'seo_url': None, 'sanction': None, 'language_code': None, 'language_id': None}, 'city': None, 'latitude': None, 'longitude': None, 'vicinity': None, 'administrative_area': None, 'full_address': None, 'administrative_area_code': None, 'postal_code': None, 'id': None}, 'true_location': None, 'local': False, 'negotiated': False, 'negotiated_bid': None, 'time_free_bids_expire': 1710174097, 'can_post_review': None, 'files': None, 'user_distance': None, 'from_user_location': None, 'project_collaborations': None, 'support_sessions': None, 'track_ids': None, 'drive_files': None, 'nda_details': None, 'pool_ids': ['freelancer'], 'enterprise_ids': [], 'timeframe': None, 'deloitte_details': None, 'is_escrow_project': False, 'is_seller_kyc_required': False, 'is_buyer_kyc_required': False, 'local_details': None, 'equipment': None, 'nda_signatures_new': None, 'billing_code': None, 'enterprises': [], 'enterprise_metadata_values': None, 'project_reject_reason': {'description': None, 'message': None}, 'repost_id': None, 'client_engagement': None, 'contract_signatures': None, 'quotation_id': None, 'quotation_version_id': None, 'enterprise_linked_projects_details': None, 'equipment_groups': None, 'project_source': None, 'project_source_reference': None, 'quality_details': None, 'previous_recruiter_project_details': None, 'project_note': None, 'is_quotation_project': None, 'quotation_initial_bid': None, 'requires_upfront_funding': None, 'group_ids': []}, {'id': 37866248, 'owner_id': 1701170, 'title': 'Python and ChatGPT Tutoring Needed', 'status': 'active', 'sub_status': None, 'seo_url': 'python/Python-ChatGPT-Tutoring-Needed', 'currency': {'id': 1, 'code': 'USD', 'sign': '$', 'name': 'US Dollar', 'exchange_rate': 1.0, 'country': 'US', 'is_external': False, 'is_escrowcom_supported': True}, 'description': None, 'jobs': None, 'submitdate': 1710176292, 'preview_description': "As a beginner, I'm seeking a mentor who can effectively guide me through the exciting journey of lea", 'deleted': False, 'nonpublic': False, 'hidebids': False, 'type': 'hourly', 'bidperiod': 7, 'budget': {'minimum': 15.0, 'maximum': 25.0, 'name': None,  ...

# %%
import pandas as pd

# Assuming 'p' is your JSON data
data = p['projects']

# Flatten the data
df = pd.json_normalize(data)

# Now 'df' is a DataFrame with your flattened data
print(df)
# Out:
#           id  owner_id                                              title  \
# 0   37866322  74628051                    Instagram User Profiles Scraper
# 1   37866248   1701170                 Python and ChatGPT Tutoring Needed
# 2   37866216  75049332        AI Engineer for Natural Language Processing
# 3   37866209  74949342           Full-Stack Developer for E-Commerce Site
# 4   37866132  75050954          Python Email Filtering with Pfsense Setup
# 5   37866054  75048166             Python Expert for Diverse Tech Project
# 6   37866023  14082382  Typescript to intyeract with Telethon and Tele...
# 7   37866019  73783125                       Python Script & Telegram API
# 8   37865995  75050049            Customized Basic Calculator Development
# 9   37865881  58692612          YouTube Transcript Extractor & Downloader
# 10  37865865  74628051                  Social Media Data Extraction Tool
# 11  37865839  70808065            Python Appium Expert for Mobile Testing
# 12  37865739  18578548      JSON Creation & System Integration Specialist
# 13  37865713  67187299                      Python Code for Data Analysis
# 14  37865701  75048318                   Plaid API Asset Keys Integration
# 15  37865617  14558179                        Implement GNNs with PyTorch
# 16  37865515  66758464            Python Code Explanation - Data Analysis
# 17  37865428  52367583  Python developer and Data Scientist for making...
# 18  37865305  70791665                  Monday.com App or API Development
# 19  37865183  75045419            Niagara Framework Application Developer
# 20  37865134  68808916            Python Script for Advanced HTML Parsing
# 21  37865058  45522885               Comprehensive Email Scraping Service
# 22  37865042  52367583  Python developer and Data Scientist for making...
# 23  37865039  66716737  Profitable AI-Powered Fully Automated Trading ...
# 24  37864940  65879508        Python Programming Project for MCS Students
# 25  37864870  75043915  Python-Based Minimum Spanning Tree in Stress T...
# 26  37864855  19322440  PowerBI Interface for Manual Numerical/text Da...
# 27  37864773  50296395         Python-Based User Data Organization System
# 28  37864756  75043250  [One Time Project] Golang Migration for Python...
# 29  37864712  16476558                                         AI Python
# 30  37864353  66011896            Troubleshoot AI generated code for apps
# 31  37864349  66011896           MusicVibration code for iOS& Android app
# 32  37864228  75040122          Python & C Programming, Typing Assistance
# 33  37864197  73795513      Python and Django Framework Specialist Needed
# 34  37864139  66011896         I need a Machine Learning and Python dev\n
# 35  37864083  75039987         Python Expert for Face Recognition Project
# 36  37864010  45653681                Versatile Software Developer Needed
# 37  37863993  66742517                eCommerce Site Frontend Development
# 38  37863629    638125     Advanced Flet & FastAPI Python Tutorial -VIDEO
# 39  37863605  33335560           Python Trading Bot for Solana Blockchain
# 40  37863563  75036669              Full-Stack Developer (Filipinos Only)
# 41  37863505    442943              Advanced Legal Documents Web Scraping
# 42  37863503  68184541                                        Game design
# 43  37863451  75036004  Customizable Accounting Automation - Offline/O...
# 44  37863242  27292200  Urgent API Integration with Python with amazon...
# 45  37863134  72882119                     Python flask development  -- 2
# 46  37863119  72882119                         Python flask project  -- 2
# 47  37863085  75034430                 Property Rental Management Web App
# 48  37863017  74701712               Python Main Program Logic Refinement
# 49  37863002  72882119                              Python flask project
#
#     status sub_status                                            seo_url  \
# 0   active       None             python/Instagram-User-Profiles-Scraper
# 1   active       None              python/Python-ChatGPT-Tutoring-Needed
# 2   active       None    python/Engineer-for-Natural-Language-Processing
# 3   active       None     php/Full-Stack-Developer-for-Commerce-37866209
# 4   active       None         python/Python-Email-Filtering-with-Pfsense
# 5   active       None              python/Python-Expert-for-Diverse-Tech
# 6   active       None      typescript/Typescript-intyeract-with-Telethon
# 7   active       None                  python/Python-Script-Telegram-API
# 8   active       None  website-design/Customized-Basic-Calculator-Dev...
# 9   active       None      linux/YouTube-Transcript-Extractor-Downloader
# 10  active       None     web-scraping/Social-Media-Data-Extraction-Tool
# 11  active       None             python/Python-Appium-Expert-for-Mobile
# 12  active       None            python/JSON-Creation-System-Integration
# 13  active       None      python/Python-Code-for-Data-Analysis-37865713
# 14  active       None            python/Plaid-API-Asset-Keys-Integration
# 15  active       None                 python/Implement-GNNs-with-PyTorch
# 16  active       None  mathematics/Python-Code-Explanation-Data-Analysis
# 17  active       None         python/Python-developer-Data-Scientist-for
# 18  active       None          monday-com/Monday-com-App-API-Development
# 19  active       None  javascript/Niagara-Framework-Application-Devel...
# 20  active       None         aws-lambda/Python-Script-for-Advanced-HTML
# 21  active       None        python/Comprehensive-Email-Scraping-Service
# 22  active       None       python/Data-Analyst-For-Interview-Scheduling
# 23  active       None          python/Profitable-Powered-Fully-Automated
# 24  active       None   c-programming/Python-Programming-Project-for-MCS
# 25  active       None          python/Python-Based-Minimum-Spanning-Tree
# 26  active       None       excel/PowerBI-Interface-for-Manual-Numerical
# 27  active       None         python/Python-Based-User-Data-Organization
# 28  active       None           python/One-Time-Project-Golang-Migration
# 29  active       None                            machine-learning/Python
# 30  active       None        python/Troubleshoot-generated-code-for-apps
# 31  active       None         python/MusicVibration-code-for-iOS-Android
# 32  active       None    data-entry/Python-Programming-Typing-Assistance
# 33  active       None          python/Python-Django-Framework-Specialist
# 34  active       None            python/need-Machine-Learning-Python-dev
# 35  active       None  python/Python-Expert-for-Face-Recognition-3786...
# 36  active       None  cplusplus-programming/Versatile-Software-Devel...
# 37  active       None           html/eCommerce-Site-Frontend-Development
# 38  active       None       python/Advanced-Flet-FastAPI-Python-Tutorial
# 39  active       None      python/Python-Trading-Bot-for-Solana-37863605
# 40  active       None  mobile-app-development/Full-Stack-Developer-Fi...
# 41  active       None  web-scraping/Advanced-Legal-Documents-Web-Scra...
# 42  active       None                   game-design/Game-design-37863503
# 43  active       None      accounting/Customizable-Accounting-Automation
# 44  active       None          python/Urgent-API-Integration-with-Python
# 45  active       None           python/Python-flask-development-37863134
# 46  active       None               python/Python-flask-project-37863119
# 47  active       None          python/Property-Rental-Management-Web-App
# 48  active       None        python/Python-Main-Program-Logic-Refinement
# 49  active       None               python/Python-flask-project-37863002
#
#    description  jobs  submitdate  \
# 0         None  None  1710177697
# 1         None  None  1710176292
# 2         None  None  1710175552
# 3         None  None  1710175344
# 4         None  None  1710173837
# 5         None  None  1710172457
# 6         None  None  1710171701
# 7         None  None  1710171701
# 8         None  None  1710171210
# 9         None  None  1710169244
# 10        None  None  1710168950
# 11        None  None  1710168537
# 12        None  None  1710166452
# 13        None  None  1710166054
# 14        None  None  1710165898
# 15        None  None  1710164561
# 16        None  None  1710162669
# 17        None  None  1710160682
# 18        None  None  1710158244
# 19        None  None  1710156516
# 20        None  None  1710155321
# 21        None  None  1710154029
# 22        None  None  1710153727
# 23        None  None  1710153696
# 24        None  None  1710152906
# 25        None  None  1710151136
# 26        None  None  1710150836
# 27        None  None  1710149510
# 28        None  None  1710149313
# 29        None  None  1710148555
# 30        None  None  1710142526
# 31        None  None  1710142450
# 32        None  None  1710140585
# 33        None  None  1710140053
# 34        None  None  1710138987
# 35        None  None  1710138041
# 36        None  None  1710136283
# 37        None  None  1710136041
# 38        None  None  1710127036
# 39        None  None  1710126463
# 40        None  None  1710124884
# 41        None  None  1710123186
# 42        None  None  1710123021
# 43        None  None  1710121358
# 44        None  None  1710114395
# 45        None  None  1710112015
# 46        None  None  1710111657
# 47        None  None  1710110602
# 48        None  None  1710108182
# 49        None  None  1710107552
#
#                                   preview_description  ...  \
# 0   I'm seeking a skilled developer, proficient in...  ...
# 1   As a beginner, I'm seeking a mentor who can ef...  ...
# 2   I am looking for an AI Engineer with command o...  ...
# 3   I require a highly skilled full-stack develope...  ...
# 4   I require expert assistance to set up Pfsense ...  ...
# 5   I'm seeking a seasoned Python developer with a...  ...
# 6   Preferably coded in Typescript for faster tran...  ...
# 7   Need an expert in Telegram's API and Python sc...  ...
# 8   I am seeking a competent and inventive program...  ...
# 9   I need a proficient Python developer to design...  ...
# 10  I'm seeking a competent developer to create a ...  ...
# 11  1. Hi, how's it going? I want to automate some...  ...
# 12  I'm in need of a skilled programmer and develo...  ...
# 13  I'm in need of a skilled Python coder to creat...  ...
# 14  I am seeking an experienced developer with the...  ...
# 15  I’m seeking a Python expert with substantial e...  ...
# 16  I require a professional with a solid understa...  ...
# 17  I require a skilled data analyst with proficie...  ...
# 18  We are looking for someone to help us implemen...  ...
# 19  I'm in need of an expert in the Niagara Framew...  ...
# 20  I am looking for an experienced Python develop...  ...
# 21  I am looking to develop a versatile tool capab...  ...
# 22  I require a skilled data analyst with proficie...  ...
# 23  I'm seeking a highly skilled developer to crea...  ...
# 24  As a MCS student, I'm looking for a proficient...  ...
# 25  As an active member of the risk management sec...  ...
# 26  I'm seeking a professional who can script a us...  ...
# 27  I'm in need of a proficient Python developer, ...  ...
# 28  As an up-and-coming business, we're on the loo...  ...
# 29  I am looking for a skilled developer with an e...  ...
# 30  Looking for a blockchain and Python expect (or...  ...
# 31  We need is an app code for iOS and Android in ...  ...
# 32  I am currently seeking a professional who can ...  ...
# 33  There is an Open Source Project . https://gith...  ...
# 34  I need a skilled machine learning and python d...  ...
# 35  As part of my M.Tech project, I require a skil...  ...
# 36  I'm in search of a proficient and adaptable so...  ...
# 37  I am in need of an adept frontend developer sp...  ...
# 38  I'm looking for a Python pro to create an insi...  ...
# 39  For this project I require:\n\n* The expertise...  ...
# 40  We are looking for a full stack developer who ...  ...
# 41  Bid on some or all. Dm message me for any ques...  ...
# 42  I'm in search of a dedicated professional who ...  ...
# 43  I'm looking for a skilled developer to build a...  ...
# 44  I need someone with experience in amazon lambd...  ...
# 45  We are seeking a talented Python Developer wit...  ...
# 46  We are seeking a talented Python Developer wit...  ...
# 47  I wish to build a web app leveraging react and...  ...
# 48  I am seeking an experienced Python developer t...  ...
# 49  We are seeking a talented Python Developer wit...  ...
#
#     location.administrative_area  location.full_address  \
# 0                           None                   None
# 1                           None                   None
# 2                           None                   None
# 3                           None                   None
# 4                           None                   None
# 5                           None                   None
# 6                           None                   None
# 7                           None                   None
# 8                           None                   None
# 9                           None                   None
# 10                          None                   None
# 11                          None                   None
# 12                          None                   None
# 13                          None                   None
# 14                          None                   None
# 15                          None                   None
# 16                          None                   None
# 17                          None                   None
# 18                          None                   None
# 19                          None                   None
# 20                          None                   None
# 21                          None                   None
# 22                          None                   None
# 23                          None                   None
# 24                          None                   None
# 25                          None                   None
# 26                          None                   None
# 27                          None                   None
# 28                          None                   None
# 29                          None                   None
# 30                          None                   None
# 31                          None                   None
# 32                          None                   None
# 33                          None                   None
# 34                          None                   None
# 35                          None                   None
# 36                          None                   None
# 37                          None                   None
# 38                          None                   None
# 39                          None                   None
# 40                          None                   None
# 41                          None                   None
# 42                          None                   None
# 43                          None                   None
# 44                          None                   None
# 45                          None                   None
# 46                          None                   None
# 47                          None                   None
# 48                          None                   None
# 49                          None                   None
#
#     location.administrative_area_code location.postal_code  location.id  \
# 0                                None                 None         None
# 1                                None                 None         None
# 2                                None                 None         None
# 3                                None                 None         None
# 4                                None                 None         None
# 5                                None                 None         None
# 6                                None                 None         None
# 7                                None                 None         None
# 8                                None                 None         None
# 9                                None                 None         None
# 10                               None                 None         None
# 11                               None                 None         None
# 12                               None                 None         None
# 13                               None                 None         None
# 14                               None                 None         None
# 15                               None                 None         None
# 16                               None                 None         None
# 17                               None                 None         None
# 18                               None                 None         None
# 19                               None                 None         None
# 20                               None                 None         None
# 21                               None                 None         None
# 22                               None                 None         None
# 23                               None                 None         None
# 24                               None                 None         None
# 25                               None                 None         None
# 26                               None                 None         None
# 27                               None                 None         None
# 28                               None                 None         None
# 29                               None                 None         None
# 30                               None                 None         None
# 31                               None                 None         None
# 32                               None                 None         None
# 33                               None                 None         None
# 34                               None                 None         None
# 35                               None                 None         None
# 36                               None                 None         None
# 37                               None                 None         None
# 38                               None                 None         None
# 39                               None                 None         None
# 40                               None                 None         None
# 41                               None                 None         None
# 42                               None                 None         None
# 43                               None                 None         None
# 44                               None                 None         None
# 45                               None                 None         None
# 46                               None                 None         None
# 47                               None                 None         None
# 48                               None                 None         None
# 49                               None                 None         None
#
#                     project_reject_reason.description  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16  The project description is not meaningful.,The...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
#
#                         project_reject_reason.message  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16  Kindly provide a better and personalized proje...
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
#
#     hourly_project_info.commitment.hours  \
# 0                                    NaN
# 1                                   40.0
# 2                                   40.0
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                  40.0
# 13                                  40.0
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                  40.0
# 20                                  40.0
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                  40.0
# 25                                   NaN
# 26                                   NaN
# 27                                   NaN
# 28                                   NaN
# 29                                  40.0
# 30                                   NaN
# 31                                   NaN
# 32                                  40.0
# 33                                   NaN
# 34                                   NaN
# 35                                   NaN
# 36                                   NaN
# 37                                   NaN
# 38                                   NaN
# 39                                   NaN
# 40                                  40.0
# 41                                   NaN
# 42                                   NaN
# 43                                   NaN
# 44                                   NaN
# 45                                   NaN
# 46                                  40.0
# 47                                   NaN
# 48                                   NaN
# 49                                   NaN
#
#    hourly_project_info.commitment.interval hourly_project_info.duration_enum
# 0                                      NaN                               NaN
# 1                                     week                       unspecified
# 2                                     week                       unspecified
# 3                                      NaN                               NaN
# 4                                      NaN                               NaN
# 5                                      NaN                               NaN
# 6                                      NaN                               NaN
# 7                                      NaN                               NaN
# 8                                      NaN                               NaN
# 9                                      NaN                               NaN
# 10                                     NaN                               NaN
# 11                                     NaN                               NaN
# 12                                    week                       unspecified
# 13                                    week                       unspecified
# 14                                     NaN                               NaN
# 15                                     NaN                               NaN
# 16                                     NaN                               NaN
# 17                                     NaN                               NaN
# 18                                     NaN                               NaN
# 19                                    week                       unspecified
# 20                                    week                       unspecified
# 21                                     NaN                               NaN
# 22                                     NaN                               NaN
# 23                                     NaN                               NaN
# 24                                    week                       unspecified
# 25                                     NaN                               NaN
# 26                                     NaN                               NaN
# 27                                     NaN                               NaN
# 28                                     NaN                               NaN
# 29                                    week                       unspecified
# 30                                     NaN                               NaN
# 31                                     NaN                               NaN
# 32                                    week                       unspecified
# 33                                     NaN                               NaN
# 34                                     NaN                               NaN
# 35                                     NaN                               NaN
# 36                                     NaN                               NaN
# 37                                     NaN                               NaN
# 38                                     NaN                               NaN
# 39                                     NaN                               NaN
# 40                                    week                       unspecified
# 41                                     NaN                               NaN
# 42                                     NaN                               NaN
# 43                                     NaN                               NaN
# 44                                     NaN                               NaN
# 45                                     NaN                               NaN
# 46                                    week                       unspecified
# 47                                     NaN                               NaN
# 48                                     NaN                               NaN
# 49                                     NaN                               NaN
#
# [50 rows x 138 columns]

# %%
df.columns = df.columns.str.replace('.', '_')

# %%
columns = ['id', 'title', 'seo_url', 'submitdate', 'budget_minimum', 'budget_maximum', 'currency_code', 'currency_exchange_rate', 'bid_stats_bid_count', 'bid_stats_bid_avg']

# %%
df_filtered = df[columns]

# %%
df_filtered['budget_maximum_usd'] = df_filtered['budget_maximum'] * df_filtered['currency_exchange_rate']
df_filtered['budget_minimum_usd'] = df_filtered['budget_minimum'] * df_filtered['currency_exchange_rate']
# Out:
# /tmp/ipykernel_12318/1800933255.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['budget_maximum_usd'] = df_filtered['budget_maximum'] * df_filtered['currency_exchange_rate']
# /tmp/ipykernel_12318/1800933255.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['budget_minimum_usd'] = df_filtered['budget_minimum'] * df_filtered['currency_exchange_rate']

# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import (
    get_projects, get_project_by_id
)
from freelancersdk.resources.projects.helpers import (
    create_get_projects_object, create_get_projects_project_details_object,
    create_get_projects_user_details_object
)
from freelancersdk.resources.projects.exceptions import \
    ProjectsNotFoundException
import os
import json

def _get_project_by_id(id):
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_id = id
    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

p = _get_project_by_id(15389177)

# %%
p['description']
# Out:
# 'Hi kenniokeif, I noticed your profile and would like to offer you my project. We can discuss any details over chat. I am also residing in Jamaica and would love to discuss a business proposal. '

# %%
# Assuming 'df' is your DataFrame and 'id' is your column of IDs

# Define your function
def get_description(id):
    # Replace this with your actual function
    return _get_project_by_id(id)['description']

# Create a new column 'description' by applying 'get_description' to each ID
df_filtered['description'] = df_filtered['id'].apply(get_description)

# Now 'df' has a new column 'description' with the descriptions for each ID
print(df_filtered)
# Out:
#           id                                              title  \
# 0   37866322                    Instagram User Profiles Scraper
# 1   37866248                 Python and ChatGPT Tutoring Needed
# 2   37866216        AI Engineer for Natural Language Processing
# 3   37866209           Full-Stack Developer for E-Commerce Site
# 4   37866132          Python Email Filtering with Pfsense Setup
# 5   37866054             Python Expert for Diverse Tech Project
# 6   37866023  Typescript to intyeract with Telethon and Tele...
# 7   37866019                       Python Script & Telegram API
# 8   37865995            Customized Basic Calculator Development
# 9   37865881          YouTube Transcript Extractor & Downloader
# 10  37865865                  Social Media Data Extraction Tool
# 11  37865839            Python Appium Expert for Mobile Testing
# 12  37865739      JSON Creation & System Integration Specialist
# 13  37865713                      Python Code for Data Analysis
# 14  37865701                   Plaid API Asset Keys Integration
# 15  37865617                        Implement GNNs with PyTorch
# 16  37865515            Python Code Explanation - Data Analysis
# 17  37865428  Python developer and Data Scientist for making...
# 18  37865305                  Monday.com App or API Development
# 19  37865183            Niagara Framework Application Developer
# 20  37865134            Python Script for Advanced HTML Parsing
# 21  37865058               Comprehensive Email Scraping Service
# 22  37865042  Python developer and Data Scientist for making...
# 23  37865039  Profitable AI-Powered Fully Automated Trading ...
# 24  37864940        Python Programming Project for MCS Students
# 25  37864870  Python-Based Minimum Spanning Tree in Stress T...
# 26  37864855  PowerBI Interface for Manual Numerical/text Da...
# 27  37864773         Python-Based User Data Organization System
# 28  37864756  [One Time Project] Golang Migration for Python...
# 29  37864712                                         AI Python
# 30  37864353            Troubleshoot AI generated code for apps
# 31  37864349           MusicVibration code for iOS& Android app
# 32  37864228          Python & C Programming, Typing Assistance
# 33  37864197      Python and Django Framework Specialist Needed
# 34  37864139         I need a Machine Learning and Python dev\n
# 35  37864083         Python Expert for Face Recognition Project
# 36  37864010                Versatile Software Developer Needed
# 37  37863993                eCommerce Site Frontend Development
# 38  37863629     Advanced Flet & FastAPI Python Tutorial -VIDEO
# 39  37863605           Python Trading Bot for Solana Blockchain
# 40  37863563              Full-Stack Developer (Filipinos Only)
# 41  37863505              Advanced Legal Documents Web Scraping
# 42  37863503                                        Game design
# 43  37863451  Customizable Accounting Automation - Offline/O...
# 44  37863242  Urgent API Integration with Python with amazon...
# 45  37863134                     Python flask development  -- 2
# 46  37863119                         Python flask project  -- 2
# 47  37863085                 Property Rental Management Web App
# 48  37863017               Python Main Program Logic Refinement
# 49  37863002                              Python flask project
#
#                                               seo_url  submitdate  \
# 0              python/Instagram-User-Profiles-Scraper  1710177697
# 1               python/Python-ChatGPT-Tutoring-Needed  1710176292
# 2     python/Engineer-for-Natural-Language-Processing  1710175552
# 3      php/Full-Stack-Developer-for-Commerce-37866209  1710175344
# 4          python/Python-Email-Filtering-with-Pfsense  1710173837
# 5               python/Python-Expert-for-Diverse-Tech  1710172457
# 6       typescript/Typescript-intyeract-with-Telethon  1710171701
# 7                   python/Python-Script-Telegram-API  1710171701
# 8   website-design/Customized-Basic-Calculator-Dev...  1710171210
# 9       linux/YouTube-Transcript-Extractor-Downloader  1710169244
# 10     web-scraping/Social-Media-Data-Extraction-Tool  1710168950
# 11             python/Python-Appium-Expert-for-Mobile  1710168537
# 12            python/JSON-Creation-System-Integration  1710166452
# 13      python/Python-Code-for-Data-Analysis-37865713  1710166054
# 14            python/Plaid-API-Asset-Keys-Integration  1710165898
# 15                 python/Implement-GNNs-with-PyTorch  1710164561
# 16  mathematics/Python-Code-Explanation-Data-Analysis  1710162669
# 17         python/Python-developer-Data-Scientist-for  1710160682
# 18          monday-com/Monday-com-App-API-Development  1710158244
# 19  javascript/Niagara-Framework-Application-Devel...  1710156516
# 20         aws-lambda/Python-Script-for-Advanced-HTML  1710155321
# 21        python/Comprehensive-Email-Scraping-Service  1710154029
# 22       python/Data-Analyst-For-Interview-Scheduling  1710153727
# 23          python/Profitable-Powered-Fully-Automated  1710153696
# 24   c-programming/Python-Programming-Project-for-MCS  1710152906
# 25          python/Python-Based-Minimum-Spanning-Tree  1710151136
# 26       excel/PowerBI-Interface-for-Manual-Numerical  1710150836
# 27         python/Python-Based-User-Data-Organization  1710149510
# 28           python/One-Time-Project-Golang-Migration  1710149313
# 29                            machine-learning/Python  1710148555
# 30        python/Troubleshoot-generated-code-for-apps  1710142526
# 31         python/MusicVibration-code-for-iOS-Android  1710142450
# 32    data-entry/Python-Programming-Typing-Assistance  1710140585
# 33          python/Python-Django-Framework-Specialist  1710140053
# 34            python/need-Machine-Learning-Python-dev  1710138987
# 35  python/Python-Expert-for-Face-Recognition-3786...  1710138041
# 36  cplusplus-programming/Versatile-Software-Devel...  1710136283
# 37           html/eCommerce-Site-Frontend-Development  1710136041
# 38       python/Advanced-Flet-FastAPI-Python-Tutorial  1710127036
# 39      python/Python-Trading-Bot-for-Solana-37863605  1710126463
# 40  mobile-app-development/Full-Stack-Developer-Fi...  1710124884
# 41  web-scraping/Advanced-Legal-Documents-Web-Scra...  1710123186
# 42                   game-design/Game-design-37863503  1710123021
# 43      accounting/Customizable-Accounting-Automation  1710121358
# 44          python/Urgent-API-Integration-with-Python  1710114395
# 45           python/Python-flask-development-37863134  1710112015
# 46               python/Python-flask-project-37863119  1710111657
# 47          python/Property-Rental-Management-Web-App  1710110602
# 48        python/Python-Main-Program-Logic-Refinement  1710108182
# 49               python/Python-flask-project-37863002  1710107552
#
#     budget_minimum  budget_maximum currency_code  currency_exchange_rate  \
# 0             10.0            30.0           USD                1.000000
# 1             15.0            25.0           USD                1.000000
# 2             25.0            50.0           USD                1.000000
# 3            250.0           750.0           EUR                1.092760
# 4             30.0           250.0           USD                1.000000
# 5            250.0           750.0           USD                1.000000
# 6             30.0           250.0           USD                1.000000
# 7              8.0            10.0           EUR                1.092760
# 8            250.0           750.0           GBP                1.280893
# 9             30.0           250.0           USD                1.000000
# 10            10.0            30.0           USD                1.000000
# 11            30.0           250.0           USD                1.000000
# 12            10.0            50.0           SGD                0.751634
# 13           100.0           400.0           INR                0.012084
# 14           250.0           750.0           USD                1.000000
# 15            10.0            80.0           AUD                0.660722
# 16           250.0           750.0           AUD                0.660722
# 17            10.0            30.0           USD                1.000000
# 18            30.0           250.0           EUR                1.092760
# 19           750.0          1250.0           INR                0.012084
# 20            15.0            25.0           USD                1.000000
# 21            10.0            20.0           GBP                1.280893
# 22           600.0          1500.0           INR                0.012084
# 23           750.0          1500.0           USD                1.000000
# 24           750.0          1250.0           INR                0.012084
# 25           600.0         15000.0           INR                0.012084
# 26          1500.0         12500.0           INR                0.012084
# 27             8.0            30.0           EUR                1.092760
# 28           250.0           750.0           SGD                0.751634
# 29            18.0            36.0           EUR                1.092760
# 30          1500.0         12500.0           INR                0.012084
# 31         12500.0         37500.0           INR                0.012084
# 32           750.0          1250.0           INR                0.012084
# 33           600.0          1500.0           INR                0.012084
# 34          1500.0         12500.0           INR                0.012084
# 35          1500.0         12500.0           INR                0.012084
# 36            10.0            30.0           USD                1.000000
# 37          1500.0         12500.0           INR                0.012084
# 38            30.0           250.0           USD                1.000000
# 39           250.0           750.0           USD                1.000000
# 40             8.0            15.0           USD                1.000000
# 41            30.0           250.0           USD                1.000000
# 42            30.0           250.0           CAD                0.741583
# 43           250.0           750.0           USD                1.000000
# 44            30.0           250.0           USD                1.000000
# 45            30.0           250.0           USD                1.000000
# 46             8.0            15.0           USD                1.000000
# 47            30.0           250.0           USD                1.000000
# 48            30.0           250.0           USD                1.000000
# 49            30.0           250.0           USD                1.000000
#
#     bid_stats_bid_count  bid_stats_bid_avg  budget_maximum_usd  \
# 0                     9          28.000000            30.00000
# 1                    41          22.390244            25.00000
# 2                    31          37.050000            50.00000
# 3                    92         476.086957           819.57000
# 4                    22         159.090909           250.00000
# 5                    44         461.309091           750.00000
# 6                     2         114.500000           250.00000
# 7                     8           8.625000            10.92760
# 8                    94         448.010638           960.66975
# 9                     8         180.625000           250.00000
# 10                    6          21.500000            30.00000
# 11                   15         158.000000           250.00000
# 12                   12          36.021667            37.58170
# 13                   15         278.666667             4.83360
# 14                   50         517.840000           750.00000
# 15                    7          62.142857            52.85776
# 16                   25         489.200000           495.54150
# 17                    3          45.000000            30.00000
# 18                   50         170.880000           273.19000
# 19                    6         975.000000            15.10500
# 20                   62          20.120968            25.00000
# 21                    4          15.750000            25.61786
# 22                    3        1218.333333            18.12600
# 23                   14        2047.142857          1500.00000
# 24                   19        1015.796316            15.10500
# 25                   12        8631.583333           181.26000
# 26                    9        6796.666667           151.05000
# 27                   17          28.588235            32.78280
# 28                   27         561.370370           563.72550
# 29                   66          26.406061            39.33936
# 30                    7        8405.714286           151.05000
# 31                   13       32510.769231           453.15000
# 32                   36         949.652778            15.10500
# 33                   12        2361.666667            18.12600
# 34                   19        6793.421053           151.05000
# 35                   19        7552.631579           151.05000
# 36                    7          22.142857            30.00000
# 37                   58        9934.000000           151.05000
# 38                   35         171.857143           250.00000
# 39                   22         539.636364           750.00000
# 40                   26          13.173077            15.00000
# 41                   44         166.704545           250.00000
# 42                   26         173.423077           185.39575
# 43                   23         412.478261           750.00000
# 44                   35         186.485714           250.00000
# 45                   17         153.529412           250.00000
# 46                    9          13.488889            15.00000
# 47                   42         193.214286           250.00000
# 48                   32         158.093750           250.00000
# 49                   16         137.500000           250.00000
#
#     budget_minimum_usd                                        description
# 0             10.00000  I'm seeking a skilled developer, proficient in...
# 1             15.00000  As a beginner, I'm seeking a mentor who can ef...
# 2             25.00000  I am looking for an AI Engineer with command o...
# 3            273.19000  I require a highly skilled full-stack develope...
# 4             30.00000  I require expert assistance to set up Pfsense ...
# 5            250.00000  I'm seeking a seasoned Python developer with a...
# 6             30.00000  Preferably coded in Typescript for faster tran...
# 7              8.74208  Need an expert in Telegram's API and Python sc...
# 8            320.22325  I am seeking a competent and inventive program...
# 9             30.00000  I need a proficient Python developer to design...
# 10            10.00000  I'm seeking a competent developer to create a ...
# 11            30.00000  1. Hi, how's it going? I want to automate some...
# 12             7.51634  I'm in need of a skilled programmer and develo...
# 13             1.20840  I'm in need of a skilled Python coder to creat...
# 14           250.00000  I am seeking an experienced developer with the...
# 15             6.60722  I’m seeking a Python expert with substantial e...
# 16           165.18050  I require a professional with a solid understa...
# 17            10.00000  I require a skilled data analyst with proficie...
# 18            32.78280  We are looking for someone to help us implemen...
# 19             9.06300  I'm in need of an expert in the Niagara Framew...
# 20            15.00000  I am looking for an experienced Python develop...
# 21            12.80893  I am looking to develop a versatile tool capab...
# 22             7.25040  I require a skilled data analyst with proficie...
# 23           750.00000  I'm seeking a highly skilled developer to crea...
# 24             9.06300  As a MCS student, I'm looking for a proficient...
# 25             7.25040  As an active member of the risk management sec...
# 26            18.12600  I'm seeking a professional who can script a us...
# 27             8.74208  I'm in need of a proficient Python developer, ...
# 28           187.90850  As an up-and-coming business, we're on the loo...
# 29            19.66968  I am looking for a skilled developer with an e...
# 30            18.12600  Looking for a blockchain and Python expect (or...
# 31           151.05000  We need is an app code for iOS and Android in ...
# 32             9.06300  I am currently seeking a professional who can ...
# 33             7.25040  There is an Open Source Project . https://gith...
# 34            18.12600  I need a skilled machine learning and python d...
# 35            18.12600  As part of my M.Tech project, I require a skil...
# 36            10.00000  I'm in search of a proficient and adaptable so...
# 37            18.12600  I am in need of an adept frontend developer sp...
# 38            30.00000  I'm looking for a Python pro to create an insi...
# 39           250.00000  For this project I require:\n\n* The expertise...
# 40             8.00000  We are looking for a full stack developer who ...
# 41            30.00000  Bid on some or all. Dm message me for any ques...
# 42            22.24749  I'm in search of a dedicated professional who ...
# 43           250.00000  I'm looking for a skilled developer to build a...
# 44            30.00000  I need someone with experience in amazon lambd...
# 45            30.00000  We are seeking a talented Python Developer wit...
# 46             8.00000  We are seeking a talented Python Developer wit...
# 47            30.00000  I wish to build a web app leveraging react and...
# 48            30.00000  I am seeking an experienced Python developer t...
# 49            30.00000  We are seeking a talented Python Developer wit...
# /tmp/ipykernel_12318/1418647786.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['description'] = df_filtered['id'].apply(get_description)

# %%
from datetime import datetime

df_filtered['submitdate'] = df_filtered['submitdate'].apply(lambda x: datetime.utcfromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# /tmp/ipykernel_12318/2917641104.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['submitdate'] = df_filtered['submitdate'].apply(lambda x: datetime.utcfromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'))

# %%
df_final = df_filtered

# %%
df_final.dtypes
# Out:
# id                          int64
# title                      object
# seo_url                    object
# submitdate                 object
# budget_minimum            float64
# budget_maximum            float64
# currency_code              object
# currency_exchange_rate    float64
# bid_stats_bid_count         int64
# bid_stats_bid_avg         float64
# budget_maximum_usd        float64
# budget_minimum_usd        float64
# description                object
# dtype: object

# %%
df_final['submitdate'] = pd.to_datetime(df_final['submitdate'])
# Out:
# /tmp/ipykernel_12318/59482312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['submitdate'] = pd.to_datetime(df_final['submitdate'])

# %%
df_final.dtypes
# Out:
# id                                 int64
# title                             object
# seo_url                           object
# submitdate                datetime64[ns]
# budget_minimum                   float64
# budget_maximum                   float64
# currency_code                     object
# currency_exchange_rate           float64
# bid_stats_bid_count                int64
# bid_stats_bid_avg                float64
# budget_maximum_usd               float64
# budget_minimum_usd               float64
# description                       object
# dtype: object

# %%
df_final
# Out:
#           id                                              title  \
# 0   37866322                    Instagram User Profiles Scraper
# 1   37866248                 Python and ChatGPT Tutoring Needed
# 2   37866216        AI Engineer for Natural Language Processing
# 3   37866209           Full-Stack Developer for E-Commerce Site
# 4   37866132          Python Email Filtering with Pfsense Setup
# 5   37866054             Python Expert for Diverse Tech Project
# 6   37866023  Typescript to intyeract with Telethon and Tele...
# 7   37866019                       Python Script & Telegram API
# 8   37865995            Customized Basic Calculator Development
# 9   37865881          YouTube Transcript Extractor & Downloader
# 10  37865865                  Social Media Data Extraction Tool
# 11  37865839            Python Appium Expert for Mobile Testing
# 12  37865739      JSON Creation & System Integration Specialist
# 13  37865713                      Python Code for Data Analysis
# 14  37865701                   Plaid API Asset Keys Integration
# 15  37865617                        Implement GNNs with PyTorch
# 16  37865515            Python Code Explanation - Data Analysis
# 17  37865428  Python developer and Data Scientist for making...
# 18  37865305                  Monday.com App or API Development
# 19  37865183            Niagara Framework Application Developer
# 20  37865134            Python Script for Advanced HTML Parsing
# 21  37865058               Comprehensive Email Scraping Service
# 22  37865042  Python developer and Data Scientist for making...
# 23  37865039  Profitable AI-Powered Fully Automated Trading ...
# 24  37864940        Python Programming Project for MCS Students
# 25  37864870  Python-Based Minimum Spanning Tree in Stress T...
# 26  37864855  PowerBI Interface for Manual Numerical/text Da...
# 27  37864773         Python-Based User Data Organization System
# 28  37864756  [One Time Project] Golang Migration for Python...
# 29  37864712                                         AI Python
# 30  37864353            Troubleshoot AI generated code for apps
# 31  37864349           MusicVibration code for iOS& Android app
# 32  37864228          Python & C Programming, Typing Assistance
# 33  37864197      Python and Django Framework Specialist Needed
# 34  37864139         I need a Machine Learning and Python dev\n
# 35  37864083         Python Expert for Face Recognition Project
# 36  37864010                Versatile Software Developer Needed
# 37  37863993                eCommerce Site Frontend Development
# 38  37863629     Advanced Flet & FastAPI Python Tutorial -VIDEO
# 39  37863605           Python Trading Bot for Solana Blockchain
# 40  37863563              Full-Stack Developer (Filipinos Only)
# 41  37863505              Advanced Legal Documents Web Scraping
# 42  37863503                                        Game design
# 43  37863451  Customizable Accounting Automation - Offline/O...
# 44  37863242  Urgent API Integration with Python with amazon...
# 45  37863134                     Python flask development  -- 2
# 46  37863119                         Python flask project  -- 2
# 47  37863085                 Property Rental Management Web App
# 48  37863017               Python Main Program Logic Refinement
# 49  37863002                              Python flask project
#
#                                               seo_url          submitdate  \
# 0              python/Instagram-User-Profiles-Scraper 2024-03-11 17:21:37
# 1               python/Python-ChatGPT-Tutoring-Needed 2024-03-11 16:58:12
# 2     python/Engineer-for-Natural-Language-Processing 2024-03-11 16:45:52
# 3      php/Full-Stack-Developer-for-Commerce-37866209 2024-03-11 16:42:24
# 4          python/Python-Email-Filtering-with-Pfsense 2024-03-11 16:17:17
# 5               python/Python-Expert-for-Diverse-Tech 2024-03-11 15:54:17
# 6       typescript/Typescript-intyeract-with-Telethon 2024-03-11 15:41:41
# 7                   python/Python-Script-Telegram-API 2024-03-11 15:41:41
# 8   website-design/Customized-Basic-Calculator-Dev... 2024-03-11 15:33:30
# 9       linux/YouTube-Transcript-Extractor-Downloader 2024-03-11 15:00:44
# 10     web-scraping/Social-Media-Data-Extraction-Tool 2024-03-11 14:55:50
# 11             python/Python-Appium-Expert-for-Mobile 2024-03-11 14:48:57
# 12            python/JSON-Creation-System-Integration 2024-03-11 14:14:12
# 13      python/Python-Code-for-Data-Analysis-37865713 2024-03-11 14:07:34
# 14            python/Plaid-API-Asset-Keys-Integration 2024-03-11 14:04:58
# 15                 python/Implement-GNNs-with-PyTorch 2024-03-11 13:42:41
# 16  mathematics/Python-Code-Explanation-Data-Analysis 2024-03-11 13:11:09
# 17         python/Python-developer-Data-Scientist-for 2024-03-11 12:38:02
# 18          monday-com/Monday-com-App-API-Development 2024-03-11 11:57:24
# 19  javascript/Niagara-Framework-Application-Devel... 2024-03-11 11:28:36
# 20         aws-lambda/Python-Script-for-Advanced-HTML 2024-03-11 11:08:41
# 21        python/Comprehensive-Email-Scraping-Service 2024-03-11 10:47:09
# 22       python/Data-Analyst-For-Interview-Scheduling 2024-03-11 10:42:07
# 23          python/Profitable-Powered-Fully-Automated 2024-03-11 10:41:36
# 24   c-programming/Python-Programming-Project-for-MCS 2024-03-11 10:28:26
# 25          python/Python-Based-Minimum-Spanning-Tree 2024-03-11 09:58:56
# 26       excel/PowerBI-Interface-for-Manual-Numerical 2024-03-11 09:53:56
# 27         python/Python-Based-User-Data-Organization 2024-03-11 09:31:50
# 28           python/One-Time-Project-Golang-Migration 2024-03-11 09:28:33
# 29                            machine-learning/Python 2024-03-11 09:15:55
# 30        python/Troubleshoot-generated-code-for-apps 2024-03-11 07:35:26
# 31         python/MusicVibration-code-for-iOS-Android 2024-03-11 07:34:10
# 32    data-entry/Python-Programming-Typing-Assistance 2024-03-11 07:03:05
# 33          python/Python-Django-Framework-Specialist 2024-03-11 06:54:13
# 34            python/need-Machine-Learning-Python-dev 2024-03-11 06:36:27
# 35  python/Python-Expert-for-Face-Recognition-3786... 2024-03-11 06:20:41
# 36  cplusplus-programming/Versatile-Software-Devel... 2024-03-11 05:51:23
# 37           html/eCommerce-Site-Frontend-Development 2024-03-11 05:47:21
# 38       python/Advanced-Flet-FastAPI-Python-Tutorial 2024-03-11 03:17:16
# 39      python/Python-Trading-Bot-for-Solana-37863605 2024-03-11 03:07:43
# 40  mobile-app-development/Full-Stack-Developer-Fi... 2024-03-11 02:41:24
# 41  web-scraping/Advanced-Legal-Documents-Web-Scra... 2024-03-11 02:13:06
# 42                   game-design/Game-design-37863503 2024-03-11 02:10:21
# 43      accounting/Customizable-Accounting-Automation 2024-03-11 01:42:38
# 44          python/Urgent-API-Integration-with-Python 2024-03-10 23:46:35
# 45           python/Python-flask-development-37863134 2024-03-10 23:06:55
# 46               python/Python-flask-project-37863119 2024-03-10 23:00:57
# 47          python/Property-Rental-Management-Web-App 2024-03-10 22:43:22
# 48        python/Python-Main-Program-Logic-Refinement 2024-03-10 22:03:02
# 49               python/Python-flask-project-37863002 2024-03-10 21:52:32
#
#     budget_minimum  budget_maximum currency_code  currency_exchange_rate  \
# 0             10.0            30.0           USD                1.000000
# 1             15.0            25.0           USD                1.000000
# 2             25.0            50.0           USD                1.000000
# 3            250.0           750.0           EUR                1.092760
# 4             30.0           250.0           USD                1.000000
# 5            250.0           750.0           USD                1.000000
# 6             30.0           250.0           USD                1.000000
# 7              8.0            10.0           EUR                1.092760
# 8            250.0           750.0           GBP                1.280893
# 9             30.0           250.0           USD                1.000000
# 10            10.0            30.0           USD                1.000000
# 11            30.0           250.0           USD                1.000000
# 12            10.0            50.0           SGD                0.751634
# 13           100.0           400.0           INR                0.012084
# 14           250.0           750.0           USD                1.000000
# 15            10.0            80.0           AUD                0.660722
# 16           250.0           750.0           AUD                0.660722
# 17            10.0            30.0           USD                1.000000
# 18            30.0           250.0           EUR                1.092760
# 19           750.0          1250.0           INR                0.012084
# 20            15.0            25.0           USD                1.000000
# 21            10.0            20.0           GBP                1.280893
# 22           600.0          1500.0           INR                0.012084
# 23           750.0          1500.0           USD                1.000000
# 24           750.0          1250.0           INR                0.012084
# 25           600.0         15000.0           INR                0.012084
# 26          1500.0         12500.0           INR                0.012084
# 27             8.0            30.0           EUR                1.092760
# 28           250.0           750.0           SGD                0.751634
# 29            18.0            36.0           EUR                1.092760
# 30          1500.0         12500.0           INR                0.012084
# 31         12500.0         37500.0           INR                0.012084
# 32           750.0          1250.0           INR                0.012084
# 33           600.0          1500.0           INR                0.012084
# 34          1500.0         12500.0           INR                0.012084
# 35          1500.0         12500.0           INR                0.012084
# 36            10.0            30.0           USD                1.000000
# 37          1500.0         12500.0           INR                0.012084
# 38            30.0           250.0           USD                1.000000
# 39           250.0           750.0           USD                1.000000
# 40             8.0            15.0           USD                1.000000
# 41            30.0           250.0           USD                1.000000
# 42            30.0           250.0           CAD                0.741583
# 43           250.0           750.0           USD                1.000000
# 44            30.0           250.0           USD                1.000000
# 45            30.0           250.0           USD                1.000000
# 46             8.0            15.0           USD                1.000000
# 47            30.0           250.0           USD                1.000000
# 48            30.0           250.0           USD                1.000000
# 49            30.0           250.0           USD                1.000000
#
#     bid_stats_bid_count  bid_stats_bid_avg  budget_maximum_usd  \
# 0                     9          28.000000            30.00000
# 1                    41          22.390244            25.00000
# 2                    31          37.050000            50.00000
# 3                    92         476.086957           819.57000
# 4                    22         159.090909           250.00000
# 5                    44         461.309091           750.00000
# 6                     2         114.500000           250.00000
# 7                     8           8.625000            10.92760
# 8                    94         448.010638           960.66975
# 9                     8         180.625000           250.00000
# 10                    6          21.500000            30.00000
# 11                   15         158.000000           250.00000
# 12                   12          36.021667            37.58170
# 13                   15         278.666667             4.83360
# 14                   50         517.840000           750.00000
# 15                    7          62.142857            52.85776
# 16                   25         489.200000           495.54150
# 17                    3          45.000000            30.00000
# 18                   50         170.880000           273.19000
# 19                    6         975.000000            15.10500
# 20                   62          20.120968            25.00000
# 21                    4          15.750000            25.61786
# 22                    3        1218.333333            18.12600
# 23                   14        2047.142857          1500.00000
# 24                   19        1015.796316            15.10500
# 25                   12        8631.583333           181.26000
# 26                    9        6796.666667           151.05000
# 27                   17          28.588235            32.78280
# 28                   27         561.370370           563.72550
# 29                   66          26.406061            39.33936
# 30                    7        8405.714286           151.05000
# 31                   13       32510.769231           453.15000
# 32                   36         949.652778            15.10500
# 33                   12        2361.666667            18.12600
# 34                   19        6793.421053           151.05000
# 35                   19        7552.631579           151.05000
# 36                    7          22.142857            30.00000
# 37                   58        9934.000000           151.05000
# 38                   35         171.857143           250.00000
# 39                   22         539.636364           750.00000
# 40                   26          13.173077            15.00000
# 41                   44         166.704545           250.00000
# 42                   26         173.423077           185.39575
# 43                   23         412.478261           750.00000
# 44                   35         186.485714           250.00000
# 45                   17         153.529412           250.00000
# 46                    9          13.488889            15.00000
# 47                   42         193.214286           250.00000
# 48                   32         158.093750           250.00000
# 49                   16         137.500000           250.00000
#
#     budget_minimum_usd                                        description
# 0             10.00000  I'm seeking a skilled developer, proficient in...
# 1             15.00000  As a beginner, I'm seeking a mentor who can ef...
# 2             25.00000  I am looking for an AI Engineer with command o...
# 3            273.19000  I require a highly skilled full-stack develope...
# 4             30.00000  I require expert assistance to set up Pfsense ...
# 5            250.00000  I'm seeking a seasoned Python developer with a...
# 6             30.00000  Preferably coded in Typescript for faster tran...
# 7              8.74208  Need an expert in Telegram's API and Python sc...
# 8            320.22325  I am seeking a competent and inventive program...
# 9             30.00000  I need a proficient Python developer to design...
# 10            10.00000  I'm seeking a competent developer to create a ...
# 11            30.00000  1. Hi, how's it going? I want to automate some...
# 12             7.51634  I'm in need of a skilled programmer and develo...
# 13             1.20840  I'm in need of a skilled Python coder to creat...
# 14           250.00000  I am seeking an experienced developer with the...
# 15             6.60722  I’m seeking a Python expert with substantial e...
# 16           165.18050  I require a professional with a solid understa...
# 17            10.00000  I require a skilled data analyst with proficie...
# 18            32.78280  We are looking for someone to help us implemen...
# 19             9.06300  I'm in need of an expert in the Niagara Framew...
# 20            15.00000  I am looking for an experienced Python develop...
# 21            12.80893  I am looking to develop a versatile tool capab...
# 22             7.25040  I require a skilled data analyst with proficie...
# 23           750.00000  I'm seeking a highly skilled developer to crea...
# 24             9.06300  As a MCS student, I'm looking for a proficient...
# 25             7.25040  As an active member of the risk management sec...
# 26            18.12600  I'm seeking a professional who can script a us...
# 27             8.74208  I'm in need of a proficient Python developer, ...
# 28           187.90850  As an up-and-coming business, we're on the loo...
# 29            19.66968  I am looking for a skilled developer with an e...
# 30            18.12600  Looking for a blockchain and Python expect (or...
# 31           151.05000  We need is an app code for iOS and Android in ...
# 32             9.06300  I am currently seeking a professional who can ...
# 33             7.25040  There is an Open Source Project . https://gith...
# 34            18.12600  I need a skilled machine learning and python d...
# 35            18.12600  As part of my M.Tech project, I require a skil...
# 36            10.00000  I'm in search of a proficient and adaptable so...
# 37            18.12600  I am in need of an adept frontend developer sp...
# 38            30.00000  I'm looking for a Python pro to create an insi...
# 39           250.00000  For this project I require:\n\n* The expertise...
# 40             8.00000  We are looking for a full stack developer who ...
# 41            30.00000  Bid on some or all. Dm message me for any ques...
# 42            22.24749  I'm in search of a dedicated professional who ...
# 43           250.00000  I'm looking for a skilled developer to build a...
# 44            30.00000  I need someone with experience in amazon lambd...
# 45            30.00000  We are seeking a talented Python Developer wit...
# 46             8.00000  We are seeking a talented Python Developer wit...
# 47            30.00000  I wish to build a web app leveraging react and...
# 48            30.00000  I am seeking an experienced Python developer t...
# 49            30.00000  We are seeking a talented Python Developer wit...

# %%
df_final.iloc[0]
# Out:
# id                                                                 37866322
# title                                       Instagram User Profiles Scraper
# seo_url                              python/Instagram-User-Profiles-Scraper
# submitdate                                              2024-03-11 17:21:37
# budget_minimum                                                         10.0
# budget_maximum                                                         30.0
# currency_code                                                           USD
# currency_exchange_rate                                                  1.0
# bid_stats_bid_count                                                       9
# bid_stats_bid_avg                                                      28.0
# budget_maximum_usd                                                     30.0
# budget_minimum_usd                                                     10.0
# description               I'm seeking a skilled developer, proficient in...
# Name: 0, dtype: object

# %%
df_final.to_csv('projects.csv', index=False)
