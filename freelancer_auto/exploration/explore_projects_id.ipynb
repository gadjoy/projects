# %%
from freelancersdk.session import Session
from freelancersdk.resources.projects.projects import (
    get_projects, get_project_by_id
)
from freelancersdk.resources.projects.helpers import (
    create_get_projects_object, create_get_projects_project_details_object,
    create_get_projects_user_details_object
)
from freelancersdk.resources.projects.exceptions import \
    ProjectsNotFoundException
import os
import json


def sample_get_projects():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    query = create_get_projects_object(
        project_ids=[
            201,
            202,
            203,
        ],
        project_details=create_get_projects_project_details_object(
            full_description=True,
            jobs=True,
            qualifications=True,
        ),
        user_details=create_get_projects_user_details_object(
            basic=True,
            profile_description=True,
            reputation=True,
        ),
    )

    try:
        p = get_projects(session, query)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p

def sample_get_project_by_id():
    url = os.environ.get('FLN_URL')
    oauth_token = os.environ.get('FLN_OAUTH_TOKEN')
    session = Session(oauth_token=oauth_token, url=url)

    project_id = 15389177
    project_details = create_get_projects_project_details_object(
        full_description=True
    )
    user_details = create_get_projects_user_details_object(
        basic=True
    )

    try:
        p = get_project_by_id(session, project_id, project_details, user_details)
    except ProjectsNotFoundException as e:
        print('Error message: {}'.format(e.message))
        print('Server response: {}'.format(e.error_code))
        return None
    else:
        return p


print('Getting multiple projects...')
p = sample_get_projects()
if p:
    print('Found projects: {}'.format(json.dumps(p)))
print('Getting a single project by ID...')

p = sample_get_project_by_id()
if p:
    print('Found a single project: {}'.format(json.dumps(p)))
# Out:
# Getting multiple projects...
# Found projects: {"projects": [{"id": 201, "owner_id": 2684, "title": "Boot to application", "status": "closed", "sub_status": "closed_expired", "seo_url": "Boot-application-project", "currency": {"id": 1, "code": "USD", "sign": "$", "name": "US Dollar", "exchange_rate": 1.0, "country": "US", "is_external": false, "is_escrowcom_supported": true}, "description": "To provide a boot sequence for ms windows such that from switching on\r\nthe mains the computer loads an application and displays files on the monitor without any further interaction after switching on. i.e no passwords, start menu-application, etc.  I envisage boot - load browser - display html files (starting with home page) It could be some other application, but browser/html files seems the most common and, because these files have to be uploaded would probably be easier. ", "jobs": [], "submitdate": 1077810438, "preview_description": "To provide a boot sequence for ms windows such that from switching on\r\nthe mains the computer loads ", "deleted": false, "nonpublic": false, "hidebids": false, "type": "fixed", "bidperiod": 5, "budget": {"minimum": null, "maximum": null, "name": null, "project_type": null, "currency_id": null}, "hourly_project_info": null, "featured": false, "urgent": false, "assisted": null, "active_prepaid_milestone": null, "bid_stats": {"bid_count": 2, "bid_avg": 10.0}, "time_submitted": 1077810438, "time_updated": null, "upgrades": {"featured": false, "sealed": false, "nonpublic": false, "fulltime": false, "urgent": false, "qualified": false, "NDA": false, "assisted": null, "active_prepaid_milestone": null, "ip_contract": false, "success_bundle": null, "non_compete": false, "project_management": false, "pf_only": false, "recruiter": null, "listed": null, "extend": null, "unpaid_recruiter": null, "premium": false, "enterprise": false}, "qualifications": [], "language": "en", "attachments": null, "hireme": false, "hireme_initial_bid": null, "invited_freelancers": null, "recommended_freelancers": null, "frontend_project_status": "complete", "nda_signatures": null, "location": {"country": {"name": null, "flag_url": null, "code": null, "highres_flag_url": null, "flag_url_cdn": null, "highres_flag_url_cdn": null, "iso3": null, "region_id": null, "phone_code": null, "demonym": null, "person": null, "seo_url": null, "sanction": null, "language_code": null, "language_id": null}, "city": null, "latitude": null, "longitude": null, "vicinity": null, "administrative_area": null, "full_address": null, "administrative_area_code": null, "postal_code": null, "id": null}, "true_location": null, "local": false, "negotiated": false, "negotiated_bid": null, "time_free_bids_expire": null, "can_post_review": null, "files": null, "user_distance": null, "from_user_location": null, "project_collaborations": null, "support_sessions": null, "track_ids": null, "drive_files": null, "nda_details": null, "pool_ids": ["freelancer"], "enterprise_ids": [], "timeframe": null, "deloitte_details": null, "is_escrow_project": false, "is_seller_kyc_required": false, "is_buyer_kyc_required": false, "local_details": null, "equipment": null, "nda_signatures_new": null, "billing_code": null, "enterprises": [], "enterprise_metadata_values": null, "project_reject_reason": {"description": null, "message": null}, "repost_id": null, "client_engagement": null, "contract_signatures": null, "quotation_id": null, "quotation_version_id": null, "enterprise_linked_projects_details": null, "equipment_groups": null, "project_source": null, "project_source_reference": null, "quality_details": null, "previous_recruiter_project_details": null, "project_note": null, "is_quotation_project": null, "quotation_initial_bid": null, "requires_upfront_funding": null, "group_ids": []}, {"id": 202, "owner_id": 2687, "title": "Mobile Phone Software", "status": "closed", "sub_status": "closed_expired", "seo_url": "C-C-Python/Mobile-Phone-Software", "currency": {"id": 1, "code": "USD", "sign": "$", "name": "US Dollar",  ...
# Getting a single project by ID...
# Found a single project: {"id": 15389177, "owner_id": 26905802, "title": "Project for kenniokeif", "status": "closed", "sub_status": "closed_expired", "seo_url": "advertising/Project-for-kenniokeif", "currency": {"id": 1, "code": "USD", "sign": "$", "name": "US Dollar", "exchange_rate": 1.0, "country": "US", "is_external": false, "is_escrowcom_supported": true}, "description": "Hi kenniokeif, I noticed your profile and would like to offer you my project. We can discuss any details over chat. I am also residing in Jamaica and would love to discuss a business proposal. ", "jobs": null, "submitdate": 1507878467, "preview_description": "Hi kenniokeif, I noticed your profile and would like to offer you my project. We can discuss any det", "deleted": false, "nonpublic": false, "hidebids": false, "type": "fixed", "bidperiod": 10, "budget": {"minimum": 250.0, "maximum": 250.0, "name": null, "project_type": null, "currency_id": null}, "hourly_project_info": null, "featured": false, "urgent": false, "assisted": null, "active_prepaid_milestone": null, "bid_stats": {"bid_count": 1, "bid_avg": 250.0}, "time_submitted": 1507878467, "time_updated": null, "upgrades": {"featured": false, "sealed": false, "nonpublic": false, "fulltime": false, "urgent": false, "qualified": false, "NDA": false, "assisted": null, "active_prepaid_milestone": null, "ip_contract": false, "success_bundle": null, "non_compete": false, "project_management": false, "pf_only": false, "recruiter": null, "listed": null, "extend": null, "unpaid_recruiter": null, "premium": false, "enterprise": false}, "qualifications": null, "language": "en", "attachments": null, "hireme": true, "hireme_initial_bid": null, "invited_freelancers": null, "recommended_freelancers": null, "frontend_project_status": "complete", "nda_signatures": null, "location": {"country": {"name": null, "flag_url": null, "code": null, "highres_flag_url": null, "flag_url_cdn": null, "highres_flag_url_cdn": null, "iso3": null, "region_id": null, "phone_code": null, "demonym": null, "person": null, "seo_url": null, "sanction": null, "language_code": null, "language_id": null}, "city": null, "latitude": null, "longitude": null, "vicinity": null, "administrative_area": null, "full_address": null, "administrative_area_code": null, "postal_code": null, "id": null}, "true_location": null, "local": false, "negotiated": false, "negotiated_bid": null, "time_free_bids_expire": 1507878467, "can_post_review": null, "files": null, "user_distance": null, "from_user_location": null, "project_collaborations": null, "support_sessions": null, "track_ids": null, "drive_files": null, "nda_details": null, "pool_ids": ["freelancer"], "enterprise_ids": [], "timeframe": null, "deloitte_details": null, "is_escrow_project": false, "is_seller_kyc_required": false, "is_buyer_kyc_required": false, "local_details": null, "equipment": null, "nda_signatures_new": null, "billing_code": null, "enterprises": [], "enterprise_metadata_values": null, "project_reject_reason": {"description": null, "message": null}, "repost_id": null, "client_engagement": null, "contract_signatures": null, "quotation_id": null, "quotation_version_id": null, "enterprise_linked_projects_details": null, "equipment_groups": null, "project_source": null, "project_source_reference": null, "quality_details": null, "previous_recruiter_project_details": null, "project_note": null, "is_quotation_project": null, "quotation_initial_bid": null, "requires_upfront_funding": null, "group_ids": [], "owner": {"id": 26905802, "username": "DrChung", "suspended": null, "closed": false, "is_active": null, "force_verify": null, "avatar": null, "email": null, "reputation": null, "jobs": null, "profile_description": null, "hourly_rate": null, "registration_date": 1507878466, "limited_account": false, "display_name": "DrChung", "tagline": null, "location": {"country": {"name": "Jamaica", "flag_url": null, "code": null, "highres_flag_url": null, "flag_url_cdn": null, "highres_flag_url_cdn": null ...

# %%
p
# Out:
# {'id': 15389177,
#  'owner_id': 26905802,
#  'title': 'Project for kenniokeif',
#  'status': 'closed',
#  'sub_status': 'closed_expired',
#  'seo_url': 'advertising/Project-for-kenniokeif',
#  'currency': {'id': 1,
#   'code': 'USD',
#   'sign': '$',
#   'name': 'US Dollar',
#   'exchange_rate': 1.0,
#   'country': 'US',
#   'is_external': False,
#   'is_escrowcom_supported': True},
#  'description': 'Hi kenniokeif, I noticed your profile and would like to offer you my project. We can discuss any details over chat. I am also residing in Jamaica and would love to discuss a business proposal. ',
#  'jobs': None,
#  'submitdate': 1507878467,
#  'preview_description': 'Hi kenniokeif, I noticed your profile and would like to offer you my project. We can discuss any det',
#  'deleted': False,
#  'nonpublic': False,
#  'hidebids': False,
#  'type': 'fixed',
#  'bidperiod': 10,
#  'budget': {'minimum': 250.0,
#   'maximum': 250.0,
#   'name': None,
#   'project_type': None,
#   'currency_id': None},
#  'hourly_project_info': None,
#  'featured': False,
#  'urgent': False,
#  'assisted': None,
#  'active_prepaid_milestone': None,
#  'bid_stats': {'bid_count': 1, 'bid_avg': 250.0},
#  'time_submitted': 1507878467,
#  'time_updated': None,
#  'upgrades': {'featured': False,
#   'sealed': False,
#   'nonpublic': False,
#   'fulltime': False,
#   'urgent': False,
#   'qualified': False,
#   'NDA': False,
#   'assisted': None,
#   'active_prepaid_milestone': None,
#   'ip_contract': False,
#   'success_bundle': None,
#   'non_compete': False,
#   'project_management': False,
#   'pf_only': False,
#   'recruiter': None,
#   'listed': None,
#   'extend': None,
#   'unpaid_recruiter': None,
#   'premium': False,
#   'enterprise': False},
#  'qualifications': None,
#  'language': 'en',
#  'attachments': None,
#  'hireme': True,
#  'hireme_initial_bid': None,
#  'invited_freelancers': None,
#  'recommended_freelancers': None,
#  'frontend_project_status': 'complete',
#  'nda_signatures': None,
#  'location': {'country': {'name': None,
#    'flag_url': None,
#    'code': None,
#    'highres_flag_url': None,
#    'flag_url_cdn': None,
#    'highres_flag_url_cdn': None,
#    'iso3': None,
#    'region_id': None,
#    'phone_code': None,
#    'demonym': None,
#    'person': None,
#    'seo_url': None,
#    'sanction': None,
#    'language_code': None,
#    'language_id': None},
#   'city': None,
#   'latitude': None,
#   'longitude': None,
#   'vicinity': None,
#   'administrative_area': None,
#   'full_address': None,
#   'administrative_area_code': None,
#   'postal_code': None,
#   'id': None},
#  'true_location': None,
#  'local': False,
#  'negotiated': False,
#  'negotiated_bid': None,
#  'time_free_bids_expire': 1507878467,
#  'can_post_review': None,
#  'files': None,
#  'user_distance': None,
#  'from_user_location': None,
#  'project_collaborations': None,
#  'support_sessions': None,
#  'track_ids': None,
#  'drive_files': None,
#  'nda_details': None,
#  'pool_ids': ['freelancer'],
#  'enterprise_ids': [],
#  'timeframe': None,
#  'deloitte_details': None,
#  'is_escrow_project': False,
#  'is_seller_kyc_required': False,
#  'is_buyer_kyc_required': False,
#  'local_details': None,
#  'equipment': None,
#  'nda_signatures_new': None,
#  'billing_code': None,
#  'enterprises': [],
#  'enterprise_metadata_values': None,
#  'project_reject_reason': {'description': None, 'message': None},
#  'repost_id': None,
#  'client_engagement': None,
#  'contract_signatures': None,
#  'quotation_id': None,
#  'quotation_version_id': None,
#  'enterprise_linked_projects_details': None,
#  'equipment_groups': None,
#  'project_source': None,
#  'project_source_reference': None,
#  'quality_details': None,
#  'previous_recruiter_project_details': None,
#  'project_note': None,
#  'is_quotation_project': None,
#  'quotation_initial_bid': None,
#  'requires_upfront_funding': None,
#  'group_ids': [],
#  'owner': {'id': 26905802,
#   'username': 'DrChung',
#   'suspended': None,
#   'closed': False,
#   'is_active': None,
#   'force_verify': None,
#   'avatar': None,
#   'email': None,
#   'reputation': None,
#   'jobs': None,
#   'profile_description': None,
#   'hourly_rate': None,
#   'registration_date': 1507878466,
#   'limited_account': False,
#   'display_name': 'DrChung',
#   'tagline': None,
#   'location': {'country': {'name': 'Jamaica',
#     'flag_url': None,
#     'code': None,
#     'highres_flag_url': None,
#     'flag_url_cdn': None,
#     'highres_flag_url_cdn': None,
#     'iso3': None,
#     'region_id': None,
#     'phone_code': None,
#     'demonym': None,
#     'person': None,
#     'seo_url': None,
#     'sanction': None,
#     'language_code': None,
#     'language_id': None},
#    'city': None,
#    'latitude': None,
#    'longitude': None,
#    'vicinity': None,
#    'administrative_area': None,
#    'full_address': None,
#    'administrative_area_code': None,
#    'postal_code': None,
#    'id': None},
#   'avatar_large': None,
#   'role': 'employer',
#   'chosen_role': 'employer',
#   'employer_reputation': None,
#   'status': {'payment_verified': None,
#    'email_verified': True,
#    'deposit_made': None,
#    'profile_complete': None,
#    'phone_verified': None,
#    'identity_verified': None,
#    'facebook_connected': None,
#    'freelancer_verified_user': None,
#    'linkedin_connected': None,
#    'custom_charge_verified': None},
#   'avatar_cdn': None,
#   'avatar_large_cdn': None,
#   'primary_currency': {'id': 1,
#    'code': 'USD',
#    'sign': '$',
#    'name': 'US Dollar',
#    'exchange_rate': 1.0,
#    'country': 'US',
#    'is_external': None,
#    'is_escrowcom_supported': None},
#   'account_balances': None,
#   'membership_package': None,
#   'qualifications': None,
#   'badges': None,
#   'primary_language': 'en',
#   'search_languages': None,
#   'cover_image': None,
#   'true_location': None,
#   'portfolio_count': None,
#   'preferred_freelancer': None,
#   'support_status': None,
#   'first_name': None,
#   'last_name': None,
#   'mobile_tracking': None,
#   'corporate': None,
#   'public_name': 'DrChung',
#   'corporate_users': None,
#   'is_local': None,
#   'address': None,
#   'company': None,
#   'recommendations': None,
#   'pool_ids': [],
#   'enterprise_ids': [],
#   'date_of_birth': None,
#   'escrowcom_account_linked': None,
#   'escrowcom_interaction_required': False,
#   'marketing_mobile_number': None,
#   'user_sanctions': None,
#   'freelancer_verified_status': None,
#   'secure_phone': None,
#   'directory_follow_preferences': None,
#   'is_payment_confirmation_required': None,
#   'is_nominated_payment_controlled': None,
#   'is_nominated_payment_share_setup_complete': None,
#   'enterprises': [],
#   'spam_profile': None,
#   'endorsements': None,
#   'timezone': {'id': 102,
#    'country': 'JM',
#    'timezone': 'America/Jamaica',
#    'offset': 19.0},
#   'responsiveness': None,
#   'bid_quality_details': None,
#   'test_user': None,
#   'online_offline_status': None,
#   'deposit_methods': None,
#   'oauth_password_credentials_allowed': False,
#   'registration_completed': True,
#   'is_profile_visible': True,
#   'enterprise_metadata_values': None,
#   'mfa': None,
#   'grants': None,
#   'operating_areas': None,
#   'equipment_groups': None,
#   'quality_details': None,
#   'avatar_xlarge': None,
#   'avatar_xlarge_cdn': None,
#   'document_submissions': None,
#   'rising_star_status': None,
#   'is_shareholder': None,
#   'has_marketing_mobile_number': None,
#   'is_staff': None}}

# %%
import pandas as pd

# Assuming 'p' is your JSON data
data = p

# Flatten the data
df_project = pd.json_normalize(data)

# Now 'df_project' is a DataFrame with your flattened data
print(df_project)

df_project.to_csv('df_project.csv', index=False)
# Out:
#          id  owner_id                   title  status      sub_status  \
# 0  15389177  26905802  Project for kenniokeif  closed  closed_expired
#
#                               seo_url  \
# 0  advertising/Project-for-kenniokeif
#
#                                          description  jobs  submitdate  \
# 0  Hi kenniokeif, I noticed your profile and woul...  None  1507878467
#
#                                  preview_description  ...  \
# 0  Hi kenniokeif, I noticed your profile and woul...  ...
#
#    owner.operating_areas  owner.equipment_groups  owner.quality_details  \
# 0                   None                    None                   None
#
#   owner.avatar_xlarge  owner.avatar_xlarge_cdn owner.document_submissions  \
# 0                None                     None                       None
#
#    owner.rising_star_status  owner.is_shareholder  \
# 0                      None                  None
#
#   owner.has_marketing_mobile_number owner.is_staff
# 0                              None           None
#
# [1 rows x 261 columns]
